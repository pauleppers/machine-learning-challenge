# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd
import joblib  # for saving model

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()

# X = df.drop('koi_disposition', axis=1)
X = df.drop(['koi_disposition','koi_srad','koi_slogg', 'koi_insol_err2','koi_slogg_err1'
            ,'koi_prad_err2','koi_tce_plnt_num','koi_teq','koi_insol','koi_impact_err2'
            ,'koi_depth','koi_srad_err2','koi_kepmag','koi_period_err1','koi_duration_err1'
            , 'koi_time0bk_err1', 'koi_period_err2','koi_steff', 'koi_prad_err1', 'koi_impact_err1'
            , 'koi_depth_err2', 'koi_slogg_err2', 'koi_depth_err1', 'koi_duration_err2', 'koi_duration'
            , 'koi_steff_err1', 'koi_time0bk_err2'
             ,], axis = 1)
y = df['koi_disposition']

# %% [markdown]
# ##  Apply One-Hot Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# Label encode data set to 0, 1 or 2
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
for label, original_class in zip(encoded_y, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# ...

# %%
from tensorflow.keras.utils import to_categorical
one_hot_y = to_categorical(encoded_y)
one_hot_y
label_encoder.classes_
# Out:
# C:\Users\paule\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\paule\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\paule\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
# X = pd.get_dummies(X)
X_train, X_test, y_train, y_test = train_test_split(X, one_hot_y, random_state=42)

# %%
X_train[:1]
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
#
#       koi_time0bk  koi_impact  koi_prad  koi_insol_err1  koi_model_snr  \
# 6122    133.07724        0.15      1.24          204.89           10.8
#
#       koi_steff_err2  koi_srad_err1         ra        dec
# 6122            -171           0.31  294.40472  39.351681

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
# Scale X to ensure equal weight
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

# use this for Standard scaling
# from sklearn.preprocessing import StandardScaler
# X_scaler = StandardScaler().fit(X_train)

# Transform the training and testing data using X_scaler
X_trained_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_trained_scaled.shape
# Out:
# (5243, 14)

# %% [markdown]
# # Train the Model

# %%
#Create a Deep Learning Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense  # same # neurons, neuron gets signal from previous layer

model = Sequential()
model.add(Dense(units=50, input_dim=X_trained_scaled.shape[1], activation='relu'))  # relu for regression >=0 output
model.add(Dense(units=3, activation='softmax')) # output probablity 0-1
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\paule\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 50)                750
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 153
# ...
# Total params: 903
# Trainable params: 903
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
             metrics=['accuracy'])

# Fit the model to the training data
model.fit(
    X_trained_scaled,
    y_train,
    epochs=60,
    shuffle=True,
    verbose=0
)

# model.predict([X_test_scaled])
# Quantify our Trained Model
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test, verbose=0)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
#epoch = 600 Normal Neural Network - Loss: 0.7714941046398892, Accuracy: 0.8775743842124939
# reduced features, epoch = 100 Loss 0.3421185939344716, Accuracy: 0.8346682190895081
#reduced, epoch = 300   Loss: 0.36308987332972564, Accuracy: 0.8403890132904053
# reduced, epoch = 60 Loss: 0.3574535254755609, Accuracy: 0.8443936109542847
# minMAX-was scaler, epoch=60, Loss: 0.36183456261589, Accuracy: 0.820938229560852
# Out:
# Normal Neural Network - Loss: 0.36183456261589, Accuracy: 0.820938229560852

# %%
#epoch = 60 
# 1748/1748 - 0s - loss: 0.3168 - acc: 0.8924
# Normal Neural Network - Loss: 0.31677834120167747, Accuracy: 0.8924484848976135
# 1748/1748 - 0s - loss: 0.5324 - acc: 0.8684
# Deep Neural Network - Loss: 0.5323605479446647, Accuracy: 0.8684210777282715

# %% [markdown]
# # Deep Learning

# %%
# Define the Model
deep_model = Sequential()
deep_model.add(Dense(units=50, input_dim=X_trained_scaled.shape[1], activation='relu'))
deep_model.add(Dense(units=50, activation='relu'))
deep_model.add(Dense(units=y_train.shape[1], activation='softmax'))
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 50)                750
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 153
# ...
# Total params: 3,453
# Trainable params: 3,453
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
deep_model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
             metrics=['accuracy'])

# Fit the model to the training data
deep_model.fit(X_trained_scaled, y_train, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 5243/5243 - 0s - loss: 0.5999 - acc: 0.6853
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.3871 - acc: 0.7887
# Epoch 3/100
# 5243/5243 - 0s - loss: 0.3768 - acc: 0.7925
# Epoch 4/100
# 5243/5243 - 0s - loss: 0.3734 - acc: 0.7927
# Epoch 5/100
# 5243/5243 - 0s - loss: 0.3675 - acc: 0.7971
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.3663 - acc: 0.7944
# Epoch 7/100
# 5243/5243 - 0s - loss: 0.3640 - acc: 0.8009
# Epoch 8/100
# 5243/5243 - 0s - loss: 0.3638 - acc: 0.8014
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.3605 - acc: 0.8091
# Epoch 10/100
# 5243/5243 - 0s - loss: 0.3594 - acc: 0.8091
# Epoch 11/100
# 5243/5243 - 0s - loss: 0.3579 - acc: 0.8131
# Epoch 12/100
# 5243/5243 - 0s - loss: 0.3516 - acc: 0.8127
# Epoch 13/100
# 5243/5243 - 0s - loss: 0.3520 - acc: 0.8159
# Epoch 14/100
# 5243/5243 - 0s - loss: 0.3495 - acc: 0.8173
# Epoch 15/100
# 5243/5243 - 0s - loss: 0.3483 - acc: 0.8177
# Epoch 16/100
# 5243/5243 - 0s - loss: 0.3467 - acc: 0.8209
# Epoch 17/100
# ...

# %%
model_loss_deep, model_accuracy_deep = deep_model.evaluate(
    X_test_scaled, y_test, verbose=0)
print(f"Deep Neural Network - Loss: {model_loss_deep}, Accuracy: {model_accuracy_deep}")
# minmax Deep Neural Network - Loss: 0.3108148748050838, Accuracy: 0.8535469174385071
# Out:
# Deep Neural Network - Loss: 0.3108148748050838, Accuracy: 0.8535469174385071

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

# %%
# Train the model with GridSearch

# %%
print(grid2.best_params_)
print(grid2.best_score_)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
model.save('nueral_model.h5')
deep_model.save('deep_nueral_model.h5')

#load model
from tensorflow.keras.models import load_model
deep_model2 = load_model('deep_nueral_model.h5')

# filename = 'your_name.sav'
# joblib.dump(your_model, filename)

# model.save('train')

# %%
# Evalueate
model_loss, model_accuracy = deep_model2.evaluate(
    X_test_scaled, y_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1748/1748 - 0s - loss: 2.0451 - acc: 0.8690
# Normal Neural Network - Loss: 2.0451128976142514, Accuracy: 0.8689931631088257
