# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd
from sklearn import tree

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['names', 'of', 'selected', 'features', 'here']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-0a84e8f06319> in <module>
#       1 # Set features. This will also be used as your x values.
# ----> 2 selected_features = df[['names', 'of', 'selected', 'features', 'here']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['names', 'of', 'selected', 'features', 'here'], dtype='object')] are in the [columns]"

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X = df.drop('koi_disposition', axis=1)
y = df['koi_disposition']

from sklearn.model_selection import train_test_split
X = pd.get_dummies(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Single Tree
planet = tree.DecisionTreeClassifier()  #model this is one tree not a forrest
planet = planet.fit(X_train,y_train)   # train - class
print(planet.score(X_test,y_test))    # score
planet.feature_importances_
planet_df = pd.DataFrame(sorted(zip(planet.feature_importances_,X.columns), reverse=True))
planet_df
# Out:
# 0.8438215102974829
#            0                  1
# 0   0.194985      koi_fpflag_nt
# 1   0.183224      koi_fpflag_co
# 2   0.173318      koi_fpflag_ss
# 3   0.138134      koi_model_snr
# 4   0.029835      koi_fpflag_ec
# 5   0.026781         koi_impact
# 6   0.018074                dec
# 7   0.015218           koi_prad
# 8   0.014693      koi_srad_err1
# 9   0.013124        koi_time0bk
# 10  0.012606     koi_insol_err1
# 11  0.011649                 ra
# 12  0.011382     koi_steff_err2
# 13  0.011073         koi_period
# 14  0.009860   koi_time0bk_err2
# 15  0.009838     koi_steff_err1
# 16  0.009085       koi_duration
# 17  0.008197  koi_duration_err2
# 18  0.008013     koi_depth_err1
# 19  0.007644     koi_slogg_err2
# 20  0.007480     koi_depth_err2
# 21  0.007317    koi_impact_err1
# 22  0.007298      koi_prad_err1
# 23  0.006994          koi_steff
# 24  0.006297    koi_period_err2
# 25  0.006144   koi_time0bk_err1
# 26  0.005965  koi_duration_err1
# 27  0.005460    koi_period_err1
# 28  0.005105         koi_kepmag
# 29  0.005068      koi_srad_err2
# 30  0.004447          koi_depth
# 31  0.003787    koi_impact_err2
# 32  0.003763          koi_insol
# 33  0.003569            koi_teq
# 34  0.003521   koi_tce_plnt_num
# 35  0.003284      koi_prad_err2
# 36  0.002241     koi_slogg_err1
# 37  0.002238     koi_insol_err2
# 38  0.001660          koi_slogg
# 39  0.001629           koi_srad

# %%
X_train.head()

# %%
# add new data and make a prediction
new_data =[[]]
planet.predict(new_data)
planet.predict_proba(new_data)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data

# %% [markdown]
# # Train the Model

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=200)  # 200 decision trees
forest = forest.fit(X_train, y_train)  # fit with a forest all data set
print(f'Train score  {forest.score(X_train, y_train)}')  # 100/1.0  10/.994  200/1.0    1000/1.0
print(f'Test score  {forest.score(X_test, y_test)}')  # 100/0.898   10/.879   200/.900  1000/.900
# print(f"Training Data Score: {model2.score(X_train_scaled, y_train)}")
# print(f"Testing Data Score: {model2.score(X_test_scaled, y_test)}")
# Out:
# Train score  1.0
# Test score  0.9004576659038902

# %%
# feature importance
importances = forest.feature_importances_
importances
# Out:
# array([0.09793643, 0.06981057, 0.10639842, 0.03529192, 0.02297351,
#        0.01733477, 0.01770828, 0.01332956, 0.0229217 , 0.02213153,
#        0.01901214, 0.01101722, 0.01124981, 0.02136943, 0.03371033,
#        0.03367966, 0.02127863, 0.0134221 , 0.01334416, 0.04753609,
#        0.03144259, 0.0325709 , 0.01543212, 0.01512718, 0.01787417,
#        0.01549564, 0.0573404 , 0.00283654, 0.00986207, 0.03339849,
#        0.026813  , 0.00890691, 0.00869767, 0.01026785, 0.00892201,
#        0.01135501, 0.00845482, 0.0118998 , 0.0114744 , 0.01037216])

# %%
#sort Random Forest by their importance
sorted(zip(importances,X.columns), reverse=True)
# Out:
# [(0.10639841747973891, 'koi_fpflag_co'),
#  (0.09793643290008698, 'koi_fpflag_nt'),
#  (0.06981057442809877, 'koi_fpflag_ss'),
#  (0.057340398629000554, 'koi_model_snr'),
#  (0.04753608917586512, 'koi_prad'),
#  (0.035291924361196506, 'koi_fpflag_ec'),
#  (0.03371033267424206, 'koi_duration_err1'),
#  (0.03367966344821597, 'koi_duration_err2'),
#  (0.033398493936443216, 'koi_steff_err1'),
#  (0.0325708985948308, 'koi_prad_err2'),
#  (0.03144258516204936, 'koi_prad_err1'),
#  (0.026813001540596747, 'koi_steff_err2'),
#  (0.022973505989801146, 'koi_period'),
#  (0.022921699870428924, 'koi_time0bk_err1'),
#  (0.022131530860335466, 'koi_time0bk_err2'),
#  (0.021369434585769172, 'koi_duration'),
#  (0.02127863140118746, 'koi_depth'),
#  (0.01901214036055191, 'koi_impact'),
#  (0.017874173622416063, 'koi_insol_err1'),
#  (0.01770828338751951, 'koi_period_err2'),
#  (0.017334773447864275, 'koi_period_err1'),
#  (0.015495640307063099, 'koi_insol_err2'),
#  (0.01543212327524502, 'koi_teq'),
#  (0.015127175496393431, 'koi_insol'),
#  (0.013422095072453602, 'koi_depth_err1'),
#  (0.01334415507300912, 'koi_depth_err2'),
#  (0.013329558887927532, 'koi_time0bk'),
#  (0.011899804533892656, 'ra'),
#  (0.011474403408345135, 'dec'),
#  (0.011355006395882581, 'koi_srad_err1'),
#  (0.011249809448542843, 'koi_impact_err2'),
#  (0.011017222022588808, 'koi_impact_err1'),
#  (0.010372156010707097, 'koi_kepmag'),
#  (0.010267852518271343, 'koi_slogg_err2'),
#  (0.00986206613773685, 'koi_steff'),
#  (0.008922009074931042, 'koi_srad'),
#  (0.00890690709036106, 'koi_slogg'),
#  (0.008697674843596055, 'koi_slogg_err1'),
#  (0.008454815010797792, 'koi_srad_err2'),
#  (0.0028365395360161116, 'koi_tce_plnt_num')]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

# %%
# Train the model with GridSearch

# %%
print(grid2.best_params_)
print(grid2.best_score_)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
