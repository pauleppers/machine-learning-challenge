# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
import pandas as pd
import joblib  # for saving model

# %% [markdown]
# # Read the .CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# ## Select features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop(['koi_disposition'
             ,'koi_srad','koi_slogg', 'koi_insol_err2','koi_slogg_err1'
            ,'koi_prad_err2','koi_tce_plnt_num','koi_teq','koi_insol','koi_impact_err2'
            ,'koi_depth','koi_srad_err2','koi_kepmag','koi_period_err1','koi_duration_err1'
            , 'koi_time0bk_err1', 'koi_period_err2','koi_steff', 'koi_prad_err1', 'koi_impact_err1'
            , 'koi_depth_err2', 'koi_slogg_err2', 'koi_depth_err1', 'koi_duration_err2', 'koi_duration'
             ], axis = 1)   # 'koi_steff_err1', 'koi_time0bk_err2', 'koi_period', 'koi_srad_err1','dec'
y = df['koi_disposition']

# %% [markdown]
# ##  Apply One-Hot Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# Label encode data set to 0, 1 or 2
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
for label, original_class in zip(encoded_y, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# ...

# %%
from tensorflow.keras.utils import to_categorical
one_hot_y = to_categorical(encoded_y)
one_hot_y
label_encoder.classes_
# Out:
# C:\Users\paule\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\paule\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\paule\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, one_hot_y, random_state=42)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale X to ensure equal weight
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

# Transform the training and testing data using X_scaler
X_trained_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_trained_scaled.shape
# Out:
# (5243, 16)

# %% [markdown]
# # Train the Model

# %%
#Create a Deep Learning Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense  # same # neurons, neuron gets signal from previous layer

model = Sequential()
model.add(Dense(units=30, input_dim=X_trained_scaled.shape[1], activation='relu'))  # relu for regression >=0 output
model.add(Dense(units=y_train.shape[1], activation='softmax')) # output probablity 0-1
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\paule\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 30)                510
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 93
# ...
# Total params: 603
# Trainable params: 603
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
             metrics=['accuracy'])

# Fit the model to the training data
model.fit(
    X_trained_scaled,
    y_train,
    epochs=1000,
    shuffle=True,
    verbose=0
)

# Quantify our Trained Model
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test, verbose=0)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# 40/1000 Normal Neural Network - Loss: 0.5122777699605824, Accuracy: 0.8890160322189331
# 30/1000 Loss: 0.3615263437242748, Accuracy: 0.8913043737411499 Loss: 0.3717369191024614, Accuracy: 0.8867276906967163
# 50/1000 Loss: 0.29635227613099924, Accuracy: 0.8735697865486145
# *beginning Scaler 30/1000 Normal Neural Network - Loss: 0.3550397614592546, Accuracy: 0.8667048215866089
# beginning MinMax Normal Neural Network - Loss: 0.33912580311980345, Accuracy: 0.8907322883605957
# above with all features Normal Neural Network - Loss: 0.2822408057595827, Accuracy: 0.8913043737411499
# final Normal Neural Network - Loss: 0.33505188661800095, Accuracy: 0.8524027466773987
# Out:
# Normal Neural Network - Loss: 0.3338912906854049, Accuracy: 0.8930205702781677

# %% [markdown]
# # Deep Learning

# %%
# Define the Model
deep_model = Sequential()
deep_model.add(Dense(units=30, input_dim=X_trained_scaled.shape[1], activation='relu'))
deep_model.add(Dense(units=30, activation='relu'))
deep_model.add(Dense(units=y_train.shape[1], activation='softmax'))
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 30)                510
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 93
# ...
# Total params: 1,533
# Trainable params: 1,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
deep_model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
             metrics=['accuracy'])

# Fit the model to the training data
deep_model.fit(X_trained_scaled, y_train, epochs=400, shuffle=True, verbose=2)
# Out:
# Epoch 1/400
# 5243/5243 - 0s - loss: 0.6672 - acc: 0.6796
# Epoch 2/400
# 5243/5243 - 0s - loss: 0.3925 - acc: 0.7812
# Epoch 3/400
# 5243/5243 - 0s - loss: 0.3730 - acc: 0.7982
# Epoch 4/400
# 5243/5243 - 0s - loss: 0.3638 - acc: 0.8093
# Epoch 5/400
# 5243/5243 - 0s - loss: 0.3576 - acc: 0.8104
# Epoch 6/400
# 5243/5243 - 0s - loss: 0.3547 - acc: 0.8194
# Epoch 7/400
# 5243/5243 - 0s - loss: 0.3512 - acc: 0.8219
# Epoch 8/400
# 5243/5243 - 0s - loss: 0.3481 - acc: 0.8232
# Epoch 9/400
# 5243/5243 - 0s - loss: 0.3468 - acc: 0.8224
# Epoch 10/400
# 5243/5243 - 0s - loss: 0.3433 - acc: 0.8295
# Epoch 11/400
# 5243/5243 - 0s - loss: 0.3439 - acc: 0.8274
# Epoch 12/400
# 5243/5243 - 0s - loss: 0.3418 - acc: 0.8291
# Epoch 13/400
# 5243/5243 - 0s - loss: 0.3414 - acc: 0.8329
# Epoch 14/400
# 5243/5243 - 0s - loss: 0.3410 - acc: 0.8302
# Epoch 15/400
# 5243/5243 - 0s - loss: 0.3398 - acc: 0.8270
# Epoch 16/400
# 5243/5243 - 0s - loss: 0.3391 - acc: 0.8316
# Epoch 17/400
# ...

# %%
model_loss_deep, model_accuracy_deep = deep_model.evaluate(
    X_test_scaled, y_test, verbose=0)
print(f"Deep Neural Network - Loss: {model_loss_deep}, Accuracy: {model_accuracy_deep}")
# minmax Deep Neural Network - Loss: 0.3108148748050838, Accuracy: 0.8535469174385071 
# units = 50, epoch = 500 Loss: 0.5037802626939333, Accuracy: 0.8724256157875061
# units = 30 epoch = 500 Deep Neural Network - Loss: 0.3703496129480052, Accuracy: 0.8821510076522827
# 30-30   500 Deep Neural Network - Loss: 0.5805560660034895, Accuracy: 0.8581235408782959
# 30-30 1000 Deep Neural Network - Loss: 1.0756981359193745, Accuracy: 0.8295194506645203
#30-30 400 Deep Neural Network - Loss: 0.33063479719227457, Accuracy: 0.8872997760772705
# above with all features Deep Neural Network - Loss: 0.274038371014104, Accuracy: 0.8890160322189331
# epoch 300,, 16 features, Deep Neural Network - Loss: 0.33465538724609045, Accuracy: 0.8689931631088257
# Out:
# Deep Neural Network - Loss: 0.3693380612257689, Accuracy: 0.8815789222717285

# %% [markdown]
# # Hyperparameter Tuning
#
# Did not use hyper parameter tuning but options could be persued using tensorflow <br>
# https://www.tensorflow.org/tutorials/keras/keras_tuner

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
model.save('eppers_neural_model_best.h5')
# deep_model.save('eppers_deep_neural_model.h5')

#load model
from tensorflow.keras.models import load_model
model2 = load_model('eppers_neural_model_best.h5')
model2

# %%
# Evaluate
model_loss, model_accuracy = model2.evaluate(
    X_test_scaled, y_test, verbose=2)
print(
    f"Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1748/1748 - 0s - loss: 0.3339 - acc: 0.8930
# Neural Network - Loss: 0.3338912906854049, Accuracy: 0.8930205702781677
